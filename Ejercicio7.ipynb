# %% [markdown]
# Importamos las librerias necesarias

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial

# %% [markdown]
# Datos de ejemplo

# %%
X = np.array([[1, 2], [2, 3], [3, 4], [4, 5]])
y = np.array([0, 1, 2, 3])

# %% [markdown]
# Inicializamos w, b y los hiperparámetros

# %%
w = np.zeros(X.shape[1])  # Inicializa w con ceros
b = 0  # Inicializa b con 0

alpha = 0.015  # Tasa de aprendizaje
num_iterations = 100  # Número de iteraciones del descenso de gradiente

# %% [markdown]
# Definimos el algoritmo de descenso de gradiente

# %%
def gradient_descent(X, y, w, b, alpha, num_iterations):
  costs = []  # Lista para almacenar los valores de costo en cada iteración
  for i in range(num_iterations):
    theta = np.dot(X, w) + b

    dw = -np.dot(X.T, y - np.exp(theta))
    db = -np.sum(y - np.exp(theta))

    w -= alpha * dw
    b -= alpha * db
    cost = -np.sum(y * theta - np.exp(theta) - np.log(factorial(y)))
    costs.append(cost)
    print(f"Iteration {i+1}: Cost = {cost}")
  return w, b, costs

# %% [markdown]
# Entrenamos el modelo

# %%
w, b, costs = gradient_descent(X, y, w, b, alpha, num_iterations)
# Out:
# Iteration 1: Cost = 6.484906649788
# Iteration 2: Cost = 6.666118110533464
# Iteration 3: Cost = 9.830018148337313
# Iteration 4: Cost = 6.194824853429521
# Iteration 5: Cost = 8.259725947825084
# Iteration 6: Cost = 6.684556203758682
# Iteration 7: Cost = 10.205466802921297
# Iteration 8: Cost = 5.9779550879757934
# Iteration 9: Cost = 7.737984868726633
# Iteration 10: Cost = 6.745873226870627
# Iteration 11: Cost = 10.719058737962758
# Iteration 12: Cost = 5.725782434325103
# Iteration 13: Cost = 7.057191351563922
# Iteration 14: Cost = 6.757474966842393
# Iteration 15: Cost = 11.026926568112962
# Iteration 16: Cost = 5.558341581515087
# Iteration 17: Cost = 6.657824468201419
# Iteration 18: Cost = 6.683694888581222
# Iteration 19: Cost = 10.989512484199631
# Iteration 20: Cost = 5.508124019107251
# Iteration 21: Cost = 6.660648091967067
# Iteration 22: Cost = 6.672475726096872
# Iteration 23: Cost = 11.16894745147696
# Iteration 24: Cost = 5.3970788568638834
# Iteration 25: Cost = 6.423578239850098
# Iteration 26: Cost = 6.602474790836435
# Iteration 27: Cost = 11.103970472781869
# Iteration 28: Cost = 5.366836617196952
# Iteration 29: Cost = 6.465922838919089
# Iteration 30: Cost = 6.611153548478578
# Iteration 31: Cost = 11.32557139727054
# Iteration 32: Cost = 5.25488912373558
# Iteration 33: Cost = 6.192707755854183
# Iteration 34: Cost = 6.512541733405108
# Iteration 35: Cost = 11.115085761773258
# Iteration 36: Cost = 5.2776299089817575
# Iteration 37: Cost = 6.406053623313417
# Iteration 38: Cost = 6.589205623024672
# Iteration 39: Cost = 11.574954968956149
# Iteration 40: Cost = 5.106281222022101
# Iteration 41: Cost = 5.88510591284739
# Iteration 42: Cost = 6.355000140865741
# Iteration 43: Cost = 10.802034110375654
# Iteration 44: Cost = 5.311662452960132
# Iteration 45: Cost = 6.771189732199077
# Iteration 46: Cost = 6.6366103879796885
# Iteration 47: Cost = 12.049639620776892
# Iteration 48: Cost = 4.924578471028129
# Iteration 49: Cost = 5.414316358451572
# Iteration 50: Cost = 5.96277025802973
# Iteration 51: Cost = 9.502840741472493
# Iteration 52: Cost = 5.772751420953674
# Iteration 53: Cost = 8.800449406792378
# Iteration 54: Cost = 6.066942181439723
# Iteration 55: Cost = 10.026360651469775
# Iteration 56: Cost = 5.530572218083943
# Iteration 57: Cost = 7.935448545243867
# Iteration 58: Cost = 6.394294158965289
# Iteration 59: Cost = 11.4400488448631
# Iteration 60: Cost = 5.003290091814763
# Iteration 61: Cost = 5.951892436517096
# Iteration 62: Cost = 6.432477741401648
# Iteration 63: Cost = 11.69579451768686
# Iteration 64: Cost = 4.9106569384842125
# Iteration 65: Cost = 5.6707951425347485
# Iteration 66: Cost = 6.260603060453178
# Iteration 67: Cost = 11.100783812283122
# Iteration 68: Cost = 5.068515548986877
# Iteration 69: Cost = 6.351193562919163
# Iteration 70: Cost = 6.583477102839978
# Iteration 71: Cost = 12.48974474850372
# Iteration 72: Cost = 4.697532774911754
# Iteration 73: Cost = 4.995907208698357
# Iteration 74: Cost = 5.495537805530246
# Iteration 75: Cost = 8.16794390164264
# Iteration 76: Cost = 6.266818248169185
# Iteration 77: Cost = 11.337025351706565
# Iteration 78: Cost = 4.951812428350171
# Iteration 79: Cost = 6.050264824442261
# Iteration 80: Cost = 6.504136567395335
# Iteration 81: Cost = 12.374384516833024
# Iteration 82: Cost = 4.676965110431035
# Iteration 83: Cost = 5.044151783913185
# Iteration 84: Cost = 5.6165005021497105
# Iteration 85: Cost = 8.826314486944247
# Iteration 86: Cost = 5.963326213104858
# Iteration 87: Cost = 10.276144032058815
# Iteration 88: Cost = 5.307972838266359
# Iteration 89: Cost = 7.620723989645795
# Iteration 90: Cost = 6.451838750023226
# Iteration 91: Cost = 12.332754146614635
# Iteration 92: Cost = 4.651819495900967
# Iteration 93: Cost = 5.0543527273492455
# Iteration 94: Cost = 5.667199774672788
# Iteration 95: Cost = 9.176559870063139
# Iteration 96: Cost = 5.784710583802687
# Iteration 97: Cost = 9.685917655243113
# Iteration 98: Cost = 5.545217765967949
# Iteration 99: Cost = 8.722465360376276
# Iteration 100: Cost = 5.992271063476204

# %% [markdown]
# Gráfica de costo vs. época

# %%
print(f"Parámetros finales: w = {w}, b = {b}")

# Gráfica de costo vs. época
plt.plot(range(num_iterations), costs)
plt.xlabel('Época')
plt.ylabel('Costo')
plt.title('Costo vs. Época')
plt.show()
# Out:
# Parámetros finales: w = [ 0.44458218 -0.40916783], b = -0.8537500050221384
